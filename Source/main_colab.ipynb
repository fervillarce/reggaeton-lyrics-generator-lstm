# %%
from __future__ import print_function
from keras.callbacks import LambdaCallback, ModelCheckpoint, EarlyStopping
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.optimizers import RMSprop
from keras.utils.data_utils import get_file
import numpy as np
import random
import sys
import io
import re
import os


from google.colab import drive
drive.mount('/gdrive')
# %ls /gdrive

# !ls '/gdrive/My Drive/Colab Notebooks'




def get_text(txt_file):
    # Receive a txt file with html labels and return a string with all the content clean.

    with io.open(txt_file, encoding='utf-8') as f:
        text = f.read().lower()
    
    return text


def clean_text(text):
    chars_to_clean = ['\x13', '"', "'", '?', '\x92', '©', 'ª', '¬',
                      '®', '°', '³','¹', 'º', '¿', 'ç', 'ń', 'œ', 'š', 'ˆ', '̶', 'о', '—',
                      '′', '›', '‼', '♥', '♪', '\U0006192f', '\t', '!', '#', '$', '%',
                      '&', '*', '+', '-', '/', ':', ';', '<', '=', '>', '@', '\\', '^',
                      '_', '`', '~', '\x85', '¡', '¤', '¥', '¨', '\xad', '¯',
                      '±', '´', '·', '½', '×', 'ᮤ', '–', '‘', '’', '“', '”', '•', '…',
                      '\ufeff', '�', '(', ')','[', ']', '{', '}']
    
    a = ['à', 'â', 'ã', 'ä', 'å']
    e = ['è', 'ê', 'ë', 'ė']
    i = ['ì', 'î', 'ï',]
    o = ['ò', 'ô', 'õ', 'ö']
    u = ['ù', 'û', 'ü', ]
    y = ['ý', 'ÿ']
    
    # Remove html labels and add linebreaks
    text = text.replace('<p>', '')
    text = text.replace('</br></p>, ', ' \n')
    text = text.replace('<br/>', ' \n')
    text = text.replace('</p>, ', '</p>')
    text = text.replace('</p>', ' \n')
    text = text.replace('<br>', ' \n')
    text = text.replace(',', '')
    text = re.sub(r'(\(.*\)\s*)|(\[.*\]\s*)|(\{.*\}\s*)','',text)
    
    # Clean the text of strange characters
    for char in chars_to_clean:
        text = text.replace(char, '')
    for char in a:
        text = text.replace(char, 'á')
    for char in e:
        text = text.replace(char, 'é')
    for char in i:
        text = text.replace(char, 'í')
    for char in o:
        text = text.replace(char, 'ó')
    for char in u:
        text = text.replace(char, 'ú')
    for char in y:
        text = text.replace(char, 'y')
    
    text = text[:3000000]
    return text


def string_analysis(text):
    print("========== Corpus summary ==========")
    
    # Total number of characters
    print('Corpus length in characters:', len(text))
    
    # Total number of words
    text_in_words = [w for w in text.split(' ') if w.strip() != '' or w == '\n']
    print('Corpus length in words:', len(text_in_words))
    
    # Number of unique characters
    chars = sorted(list(set(text)))
    print('Total chars:', len(chars))
    
    return chars
    

def char_dictionaries(chars):
    char_indices = dict((c, i) for i, c in enumerate(chars))
    indices_char = dict((i, c) for i, c in enumerate(chars))
    return char_indices, indices_char


def cut_text(text, MAXLEN, STEP):
    # Cut the text in semi-redundant sequences of maxlen characters
    print("\n========== Text cut ==========")
    sentences = []
    next_chars = []
    for i in range(0, len(text) - MAXLEN, STEP):
        sentences.append(text[i: i + MAXLEN])
        next_chars.append(text[i + MAXLEN])
    print('Number of sequences:', len(sentences))
    return sentences, next_chars


def vectorize(sentences, next_chars, chars, MAXLEN, char_indices):
    print('\n========== Vectorization... ==========')
    X = np.zeros((len(sentences), MAXLEN, len(chars)), dtype=np.bool)
    y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
    for i, sentence in enumerate(sentences):
        for t, char in enumerate(sentence):
            X[i, t, char_indices[char]] = 1
        y[i, char_indices[next_chars[i]]] = 1
    return X, y


def build_model(MAXLEN, chars):
    # Build the model: a single LSTM
    print('\n========== Building the model... ==========')
    
    # Define the Keras model
    model = Sequential()
    model.add(LSTM(128, input_shape=(MAXLEN, len(chars))))
    # model.add(Dropout(0.2)) # to prevent overfitting?
    model.add(Dense(len(chars), activation='softmax'))

    # Compile the Keras model
    optimizer = RMSprop()
    model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    # model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['acc'])
    return model


def sample(preds, temperature=1.0):
    # Helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)


def on_epoch_end(epoch, _):
    # Function invoked at end of each epoch. Prints generated text.
    print()
    print('----- Generating text after Epoch: {}'.format(epoch))
    
    
    examples_file = os.path.join('..','gdrive','My Drive','Colab Notebooks','examples_file.txt')
    
    with io.open(examples_file, 'a', encoding='utf8') as examples_file:
        examples_file.write('\n----- Generating text after Epoch: {}\n'.format(epoch))

        start_index = random.randint(0, len(text) - MAXLEN - 1)

        for diversity in [0.2, 0.5, 1.0, 1.2]:
            generated = ''
            sentence = text[start_index: start_index + MAXLEN]
            generated += sentence
            print('----- diversity:', diversity)
            examples_file.write('\n----- Diversity:' + str(diversity) + '\n')
            print('----- Generating with seed: "' + sentence + '"')
            examples_file.write('----- Generating with seed: "' + sentence + '"\n\n')
            sys.stdout.write(generated)
            examples_file.write(generated)

            for i in range(400):
                x_pred = np.zeros((1, MAXLEN, len(chars)))
                for t, char in enumerate(sentence):
                    x_pred[0, t, char_indices[char]] = 1.

                # Make probability predictions with the model
                preds = model.predict(x_pred, verbose=0)[0]
                next_index = sample(preds, diversity)
                next_char = indices_char[next_index]

                sentence = sentence[1:] + next_char

                sys.stdout.write(next_char)
                examples_file.write(next_char)

                sys.stdout.flush()

            examples_file.write('\n')
            print()
        examples_file.write('='*80 + '\n')
        examples_file.flush()
    


if __name__ == "__main__":

    corpus = os.path.join('..','gdrive','My Drive','Colab Notebooks','lyrics.txt')
    text = get_text(corpus)
    text = clean_text(text)
    chars = string_analysis(text)
    char_indices, indices_char = char_dictionaries(chars)
    
    # Parameters: change to experiment different configurations
    MAXLEN = 40
    STEP = 3
    BATCH_SIZE = 128
    
    sentences, next_chars = cut_text(text, MAXLEN, STEP)
    X, y = vectorize(sentences, next_chars, chars, MAXLEN, char_indices)
    model = build_model(MAXLEN, chars)
    
    file_path = os.path.join('..','gdrive','My Drive','Colab Notebooks','weights.{epoch:02d}.hdf5')
    checkpointer = ModelCheckpoint(file_path, monitor='val_loss', save_best_only=False)
    print_callback = LambdaCallback(on_epoch_end=on_epoch_end)
    #early_stopping = EarlyStopping(monitor='val_acc', patience=5)
    callbacks_list = [checkpointer, print_callback]

    
    # Fit the keras model on the dataset
    model.fit(X, y,
              batch_size=BATCH_SIZE,
              epochs=40,
              callbacks=callbacks_list)

    # Save model and architecture to single file
    model.save(os.path.join('..','gdrive','My Drive','Colab Notebooks',"model.h5"))
    print("\nSaved model to disk as model.h5")
    
    # Summarize model.
    print('\n\n========== Model summary ==========\n')
    print(model.summary())
# Out:
# Using TensorFlow backend.
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /gdrive
# 'My Drive'/
# 20181024_3MM_40      lyrics.txt  project_main_chars_v2.ipynb
# 20191025_main.ipynb  Old
# ========== Corpus summary ==========
# Corpus length in characters: 3000000
# Corpus length in words: 578032
# Total chars: 45
#
# ========== Text cut ==========
# Number of sequences: 999987
#
# ========== Vectorization... ==========
#
# ========== Building the model... ==========
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3576: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3005: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Epoch 1/40
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# 999987/999987 [==============================] - 765s 765us/step - loss: 1.9979 - acc: 0.4011
#
# ----- Generating text after Epoch: 0
# ----- diversity: 0.2
# ----- Generating with seed: "re el lamento de este corazon ilusionado"
# re el lamento de este corazon ilusionado
# y se que te esta esta
# si no te viento
# y me la cara
# y tu paga es que tu quieres
# yo no te viento
# si no me hace la calle
# y tu camo a lo que te va a vada
# y lo que te gusta solo
# si tu pasa es que te va a tu para
# y te la mista en la balla
# y a no te viene
# y al te pante
# esta ella me la calla
# a la mami a la calle
# y te pasa de acuerte
# si te esta me diste
# y al mi
# yo se que te esta es que m
# ----- diversity: 0.5
# ----- Generating with seed: "re el lamento de este corazon ilusionado"
# re el lamento de este corazon ilusionado
# desescimas
# ahora la la
# la miella la las a pera
# la calión como un pata
# cuando esta me hacira la baila
# y ala no la hacer
# tu me lo ve cuarta
# sale esto se pasa
# samo a ti majan
# y si tu pegro baby
# y como si te vendos
# si se mamo
# y de sallo es que quieres se para
# y suento me disco a tu depara
# y la amanar
# te eres me la luerta que te vevien
# y ella que te esta cara
# te pogo que to no ha que
# ----- diversity: 1.0
# ----- Generating with seed: "re el lamento de este corazon ilusionado"
# re el lamento de este corazon ilusionado
# tamica hablo de fuada
# que tade thata más
# fista de unpero a lo tno fuibuen tu mejote
# ese mujre conipo amy rozaby
# vinvemos me rafinto
# y si mowe hea ne calli keoi seo it uns ir yi ulicign
# es faln in  at
# novee y agata baba
# woenichite llow y ah
# uah heh
# hay aud habba t adate ti traty ing luaz am ame .abo kunero hecesian thes baud
# é etemos
# sienes que te lo hacé
# quiere tanta los recas
# y d
# ----- diversity: 1.2
# ----- Generating with seed: "re el lamento de este corazon ilusionado"
# re el lamento de este corazon ilusionadofountuyo
# nochudos densejon paro las aguro se un laca sta en en mids yo
# ri paque espa calosquela eso dizo y ferango aruncer e te tanab
# milane todade casbaiven
# ya calle me las tadias
# todive haba yobo kue son cojemy y bayi
# ap peoso
# saque vinigosta puso y no llanaho toyo mirio y
# yo no la brecla coaliejrasliquion ncberte como que ti mu bainas a se pa dife ens coerto
# ciandonfeenas que te ientro
# Epoch 2/40
# 999987/999987 [==============================] - 752s 752us/step - loss: 1.6977 - acc: 0.4867
#
# ----- Generating text after Epoch: 1
# ----- diversity: 0.2
# ----- Generating with seed: "e porque te quiero con esta fe prohibida"
# e porque te quiero con esta fe prohibida
# y se acasa de tu cara
# y te la mana es tu cara
# a la manda el cara de mi amor
# y si tu mas a mas a esta noche
# y tu cuerpo me llama
# y te mata el corazón
# y si te mata el cara de mi corazón
# y tu me disto a mí
# y te vas a mí me paso
# y se tu paso se tu quieres
# y se que te va a esta manda
# y se se a la mana
# y si te vas a mas a mas
# si te vas a mas a mi mal
# y esta noche a la mana
# y tu cuerpo e
# ----- diversity: 0.5
# ----- Generating with seed: "e porque te quiero con esta fe prohibida"
# e porque te quiero con esta fe prohibida
# me ella es mas calar
# y la luna en la cancienta
# baby a los ashe amas de la casa
# y te mas a la mandente
# de la luz a la manda
# y a lo que no se te quiere
# si me mas a la vida
# que se sera en la cance
# y se la no vas a parar caba
# ella me calenta baby
# como es mi dice y al
# también tú eres aman deste destalo
# y la pone contiga y la nada a la cala
# dale que te deja de ti
# no se a la gana
# y me vi
# ----- diversity: 1.0
# ----- Generating with seed: "e porque te quiero con esta fe prohibida"
# e porque te quiero con esta fe prohibida
# llaki roba na na na vas pra...
# yo
# wtrrt kap you el atimp ivo jom mike sonem got gat .
# now que ton amo machan
# yan
# no tus angusa a rfegual
# pero condandolo con no les reccero
# y la egasiencie que me gustas
# baby el ojonmerados me hacez mi queñas que nos duje me duentreta
# y te dalotos a la pistibreen
# a me conde prestios
# ya quedasme nueva a puella noferida y el que la llama y que yo
# yo te
# ----- diversity: 1.2
# ----- Generating with seed: "e porque te quiero con esta fe prohibida"
# e porque te quiero con esta fe prohibidak
# tiene camatas quiere fetier celamasa
# que estú siénes ahace llevo
# yo  enfiro deños a cúpaquera más
# me gusto a ruspablizamo
# vega vomo a tra  pivilla llego oz llamante canvilo ya desato
# de ustedes senamifatar te las
# de marino
# totas toma
# que ves feren míjaglla
# nuncambo abron jonke dimeles a mamo no sí
# dilos quiero que es barnal hacertimion sin un bolgó
# una wulla drerre...
# amor soyo
# ugua
# Epoch 3/40
# 999987/999987 [==============================] - 746s 746us/step - loss: 1.5958 - acc: 0.5169
#
# ----- Generating text after Epoch: 2
# ----- diversity: 0.2
# ----- Generating with seed: "r mi es que ellas son rivales
# pero no l"
# r mi es que ellas son rivales
# pero no lo quiero en mi cama
# esto es que me deja
# y si no te voy a parar
# si me dejas que te llamas
# si me esta noche esta contigo
# con el calle de puede en la calle
# y te distillo de ti
# esta es el corazón
# y me esta es el corazón
# el corazón en el amor
# porque esto es el marde
# te voy a mi marde
# que esta contigo
# esto es el carte
# si me estas contigo
# y si te quiero a ti
# ella es mi amor
# si tu sientes
# ----- diversity: 0.5
# ----- Generating with seed: "r mi es que ellas son rivales
# pero no l"
# r mi es que ellas son rivales
# pero no lo digo
# ya con el deseo cuento
# esto es el canto
# y me esta es un entrar
# esta noche en el gatado con su ciero y si no te deba
# dejaren el corazón
# te amor en la calle
# de nadie mami camina
# la nosha me acerta me encuentra
# se que te puso por la cama
# pa que me vida se la manda
# y me queda cabrer el ganas de mi
# se que el perro
# pero no hay como a mi
# si tu chambian
# el pito y se perdicial
# si tu
# ----- diversity: 1.0
# ----- Generating with seed: "r mi es que ellas son rivales
# pero no l"
# r mi es que ellas son rivales
# pero no lo cieronde jante qué tes palyomes
# y yo sa ti
# loco quiero ser tu erto
# my ese nido de menes la escuela
# tu quitaste que le élembro mata bocella a todo
# pero conticio rimos o
# como un leamos
# la enste que despuéndo
# un nechorienko fuesto sigue
# quísemos yo lo sebrían tenivo
# y te voy a quien a dondería
# thatseen lo. far digan sestan dinero nena ellar
# vamos le emvedo
# los menos pensandoles biblo
# ----- diversity: 1.2
# ----- Generating with seed: "r mi es que ellas son rivales
# pero no l"
# r mi es que ellas son rivales
# pero no ledas
# guacsadó así
# bien levmpty volvella y no enuitra y harma haciendo ploke eras mkigil
# dime chow pan llebs timbing es pedey y bunga vamos un unarietarme
# direla lo mboh
# se levanto a lo lloga
# usa yeah
# késníde
# lokale un elejo fierté
# volable foraaheo hema a se ha iel fei mi galo
# perriflara j mámos
# zeaaylla punte
# perre tm te vierllo si penfeje más mal buncuónizilre el pero que a lo vegás
# Epoch 4/40
# 999987/999987 [==============================] - 750s 750us/step - loss: 1.5379 - acc: 0.5338
#
# ----- Generating text after Epoch: 3
# ----- diversity: 0.2
# ----- Generating with seed: "bum tu bum bum mami
# ella escucha el dem"
# bum tu bum bum mami
# ella escucha el demos
# la calle se le da a esta calle
# te después de mi corazón
# y te encanta en la cara
# y que esta noche esta calle
# esto es mi corazón
# esto es mi corazón
# esto es mi cara
# y de tu cara que estoy perdero
# y que esto es que te vas a deserte
# y a mi madia que se ama
# y el que te llegas a la cara
# esto es la calle
# esto es mi cama
# esto es la pasa
# y a mi madia de tu cara
# y me llama
# y a mi manera
#
# ----- diversity: 0.5
# ----- Generating with seed: "bum tu bum bum mami
# ella escucha el dem"
# bum tu bum bum mami
# ella escucha el demosoo
# no pare si tanto mis cantos
# y despues que esto es mi marda
# y de tu noche te gusta el marrol
# después de ti me escuentre
# en la cara de tranquilo
# sabes que se tengo como tiempo es que te amare
# por mi compa y yo no te vas a también
# y dale a dar de mi
# si me diga el celo
# esto es que esto es una noche
# y esta es el del carto
# yo le entonte mis tengo el cara
# y es que se que tengo a tener p
# ----- diversity: 1.0
# ----- Generating with seed: "bum tu bum bum mami
# ella escucha el dem"
# bum tu bum bum mami
# ella escucha el demanora eh
# soy tus que haciendo el aísteee
# hoy daddy
# ganan
# yalke no jas un sundo i
# figdetes de ese fapuro su piel
# sientas aques cuando cuerpooy
# que me tirme congracia
# yo que deswrwnty sol
# ojo to habla que me te acuerde
# tu lado
# pide beté una sucas
# no me arrenden robien con la bien
# siguelo que me peedes pal otros fecho domme
# que todo lo que te bressscan
# que al orimo prota
# van alam
# qu
# ----- diversity: 1.2
# ----- Generating with seed: "bum tu bum bum mami
# ella escucha el dem"
# bum tu bum bum mami
# ella escucha el demóo agradén...
# bebé entregotolamos....... amordados
# quien levento y no no crrohos hatere pido equiva a
# quien soquito escanzdo o
# bespor de caigarte
# todauste todo hay vima inguniliamor qué vamos le quita
# con la huelo
# dunde que yo kaga mama un hey
# yay soy yo soy fue todo no
# diresuna noche el bejay sengid oyes
# yswen gatfos y nos la clan tu lo que lligan el crazo eston traguiahte
# carrele fasano
# Epoch 5/40
# 999987/999987 [==============================] - 746s 746us/step - loss: 1.4997 - acc: 0.5451
#
# ----- Generating text after Epoch: 4
# ----- diversity: 0.2
# ----- Generating with seed: "ra que la zona esta caliente
# suena blan"
# ra que la zona esta caliente
# suena blanca
# yo soy tu cuerpo me pegaron con la calle
# y si te vas a estar contra
# y si tu quieres me tiene
# de tu cuerpo me conoce
# y se pone mi calle
# y si tu no se va a rever
# porque es que tu cuerpo me perdedo
# y si tu quieres mujer
# que tú me puedo estar contigo
# yo soy el que tu quieres me despertar
# y te voy a pegar mi corazón
# y se prestamos en la calle
# y yo soy con el corazón
# y tu cuerpo me llam
# ----- diversity: 0.5
# ----- Generating with seed: "ra que la zona esta caliente
# suena blan"
# ra que la zona esta caliente
# suena blanca
# tú sabes que tu pasas de tu canta
# sigue a su lo mismo la encante
# y en la calle esta buscando el cuello que pasan el suelto
# pero yo no quiero ver
# que tu nenas lo cuando la mejor
# solo quiero cara es ti
# si tú no puedes cuerpo mi mando
# que se a mi me mueve conmigo no lo hace
# lo que sintiencelo en nada
# y tu tu me congrasco
# y yo no tú ha con tu corazón
# estoy sin
# tu no soy un carle
# esta
# ----- diversity: 1.0
# ----- Generating with seed: "ra que la zona esta caliente
# suena blan"
# ra que la zona esta caliente
# suena blandugo
# ahora recantó dulo de velud
# no te cujan pués tú se tesprabas perionas perdriá para danala
# y no te vean tienes el rinera
# que jure y eu vele a pagarme
# sin tendrita pello grande mía
# me preumo de mi mambien
# lo has decides con el sumbeca
# adrrrrachaso
# y el jodudo que te quete todos los fajos
# que papi los mismos siempre
# yo tos controla en la palabla
# este gosión la noche está duro vanho
#
# ----- diversity: 1.2
# ----- Generating with seed: "ra que la zona esta caliente
# suena blan"
# ra que la zona esta caliente
# suena blang una cancelición
# jrmeazendome la naña destritalo palable la arepa abcano
# tensó y tiene a la leve en un hoípo solo será tu fueto mejos vudo
# y lo mismo digananial camigimos
# los filas y anda todo pocar mujer
# que lo más plabay ya no duela con orecra proke otto the segurliiste
# bandeo de uso....
# sabeando a mi me proba
# no dale papalos era prazos milos conses.
# eoáqui asintelibostiar machos derme
# Epoch 6/40
# 999987/999987 [==============================] - 757s 757us/step - loss: 1.4724 - acc: 0.5538
#
# ----- Generating text after Epoch: 5
# ----- diversity: 0.2
# ----- Generating with seed: "...
# in the ghetto which is part of the "
# ...
# in the ghetto which is part of the wanna
# you cont on the way the way you
# you cont on the way the way
# the bous i gotta can you
# what i to the baby
# i like the way you dont baby
# and it on the way
# the bous i want and it
# you con all a cant i fir the way
# i to the got the baby
# i want you got the play
# i on you bout i wanna
# the bous i love you
# the bous i the baby
# i want you want and i want
# you dont body wanna on the way
# dont
# ----- diversity: 0.5
# ----- Generating with seed: "...
# in the ghetto which is part of the "
# ...
# in the ghetto which is part of the got the ficha
# that you mami a dand baby
# it i with the way wonh we one
# the bounaing the way the way my
# the bavie me winl you
# atrang toute on the pear
# i son and you want
# i gottight on
# you bout in the way the want
# on hene mey
# on the bous in
# esta como la gata no te pone el cartón
# vamo a pegarnos un paro
# con una portunidad y lo que te cances
# para mi mirada y la estrella te va hacer
# te mi
# ----- diversity: 1.0
# ----- Generating with seed: "...
# in the ghetto which is part of the "
# ...
# in the ghetto which is part of the  im theh wind tone moven you aight
# my or shy for.my chyner neck
# gouttan in mal gome a toy boy
# in crimuito
# level tu di el dolo
# duros de mí lexto
# la misiendo como dol re
# in ya
# me fictio otra asustulciote del algos de nosotho
# para aqui
# dale cuando te pueden ver hacerte
# lo que subles me pidos
# demierento a ti pa ti más y en corrarde una mear
# la que bajo la llevar a ver han amor aquí por h
# ----- diversity: 1.2
# ----- Generating with seed: "...
# in the ghetto which is part of the "
# ...
# in the ghetto which is part of the iptet o
# bach
# uy nos otro gan pic fallo brilla
# siundo me da
# milinos
# que te riblenen el prir y polmarse
# mira calornos yo quiero
# llorarogo me el imiso
# chillando en el naticajengse que me veles
# vamo a ser echo de cuparete lo crituro que estan
# y que unpeentso
# mperialento mambennd
# ul at t
# ell getta eve rebosoon
# es chillegdo a pelsanes pideria
# cuando con el jockinza
# bailos y posas so tu caba
# Epoch 7/40
# 999987/999987 [==============================] - 749s 749us/step - loss: 1.4512 - acc: 0.5602
#
# ----- Generating text after Epoch: 6
# ----- diversity: 0.2
# ----- Generating with seed: "etter
# say your different
# who you kiddi"
# etter
# say your different
# who you kidding doss want
# the gonna bous the way
# i need you
# the blown it on the way
# i to the baby i way the bascing
# i got the baby i way the blown it on the way
# i wat i tou
# but in the way you
# the blown it on the way
# the baby i like the baby bren i way
# i to the baby in your the bous it
# i wanna baby i like the baby
# and i keeh i way the baby in your to the boun i wanna
# i got body baby i like to the b
# ----- diversity: 0.5
# ----- Generating with seed: "etter
# say your different
# who you kiddi"
# etter
# say your different
# who you kidding baby i like the doss seled
# i get they on you
# i love it like a plato
# i not its the the baby in your peent
# i de to the gust you and with that you
# i way in hee i watta on the way my tire
# you come bolin im the placa
# shorty my bivin i can flow
# and in on the dars no
# you know i way i rind a stody
# i need a starla come caline
# i way the garg lout the pacith feeling
# i no love to the way chis
# ----- diversity: 1.0
# ----- Generating with seed: "etter
# say your different
# who you kiddi"
# etter
# say your different
# who you kiddibs up aage
# to llatun lealinama pa sin dambils
# la cuarrda becando ganas
# que no me puere con el se misma ruin en un más
# que te ves reegune duego o famin
# yo tu gusta el oupueste dicen que conse la tira
# y fuera es los que lucevoos
# a esta de ohies son vientos
# y king my mambe
# daddy sto this baby
# nadie se acibir falim paden nunvo yo no se reopormon
# far sid orecistecer
# syme intera solo los cri
# ----- diversity: 1.2
# ----- Generating with seed: "etter
# say your different
# who you kiddi"
# etter
# say your different
# who you kiddiros colempe hemble ya loam
# you clubo leevutelo im
# ounarita lace brell bole
# chalvinosiboah iónual desacelono de falduendo
# ohuh
# guaguetambueobuudu
# hey
# díos  margake. m ojoneo mami prohtuete
# ella es un dy
# y misióndennomencente aberé
# estoy. mzosa moriempre moverdos
# ayorka chi el cuzute
# calientas natiente par sin moldiendo kjmbid baby
# ooooooo
# p trackrs you
# girl the way ir ts to dosts
# e
# Epoch 8/40
# 999987/999987 [==============================] - 752s 752us/step - loss: 1.4348 - acc: 0.5654
#
# ----- Generating text after Epoch: 7
# ----- diversity: 0.2
# ----- Generating with seed: "das seguir
# y el cielo parezca caer sobr"
# das seguir
# y el cielo parezca caer sobre mi cambio
# tu eres mi cambie
# y a mi palabra
# y yo te lo digo el amor
# y si tu quieres matar la manera
# y el que te voy a dar de la calle
# esta noche esta noche
# por eso es tu cara
# y a mi me prende y no me puedo a mi
# pero te voy a mañara
# y es que te vas a pasar
# esta noche a tu cara
# y a mi me llama
# si te voy a mi cara la calle
# si tu me llamas tu corazón
# y a mi me pone mal
# si tu me mata y
# ----- diversity: 0.5
# ----- Generating with seed: "das seguir
# y el cielo parezca caer sobr"
# das seguir
# y el cielo parezca caer sobre
# baby que yo te voy a dar de comente
# y si no hay una casa en el cainto
# y no me hace cuando tu piel
# mami tu cara que tu cuerpo me piensa
# el bellao que esta noche
# el desperio esta comprosita
# no es mi mado mal
# mi sueño es una tranquiendo
# te se como yo me enamoras
# estamos es mi mata
# todo esto es de tu cuerpo
# con mi marder de fuera de tu entra
# te pienso quiere tigura
# tu cuerpo es calient
# ----- diversity: 1.0
# ----- Generating with seed: "das seguir
# y el cielo parezca caer sobr"
# das seguir
# y el cielo parezca caer sobre que soy la calor i to lo papimi y ya veleste a mirediame la inventa
# xualme boir come lotia
# muoverno flyáz chopan ochas
# tu cabrón es mi barrioo estailera correrme
# el coramilon se xy
# ganos you see really lot el my
# seacin que empezél y pa dásdondotero
# te habamo con un lyight
# come on mucho chipe  storkes arsss
# thee mami darce a yaa
# mandiende la rake
# la duecha presión
# y me boja que nadie
# ----- diversity: 1.2
# ----- Generating with seed: "das seguir
# y el cielo parezca caer sobr"
# das seguir
# y el cielo parezca caer sobritla
# se explica ayapa tu taba
# bailsano
# ojontimas pacatada no nobora
# asi me gucha tine
# en lo partillo es para misiares
# ya usted son usted deschatandos yo sabes que vamo a bestrverlo linquinio
# in daddy yor..so daddy ok
# we iell me. the ganni tio you mojestryel round of fildistsrmbhenni blant goss down dramicnoy pari mas on
# the basman pegate vueles a esperdupir
# hacerao puesa... mi incobus e
# Epoch 9/40
# 999987/999987 [==============================] - 746s 746us/step - loss: 1.4217 - acc: 0.5694
#
# ----- Generating text after Epoch: 8
# ----- diversity: 0.2
# ----- Generating with seed: "io...ouh
# dinerolas gataslos party
# plac"
# io...ouh
# dinerolas gataslos party
# placer el carajo
# por eso es que te llamas
# y a mi me desespera
# y si te vas a desecerdor
# tengo la palabra
# y esta noche esta noche esto es una manera
# y esta calle en la calle
# y a ti te vas a desespertar
# y yo lo que te vas
# y si esta noche a ti
# y a mi me dice que no es para la mano
# y yo lo que te vas
# la pasado
# y es que te va a ver
# la verdad es la calle esta es la calle
# y a mí me dice que est
# ----- diversity: 0.5
# ----- Generating with seed: "io...ouh
# dinerolas gataslos party
# plac"
# io...ouh
# dinerolas gataslos party
# placer
# se pega le gusta la calle
# y es amor a mi me puede ver
# y es corre la disco es que estamos por el trajo
# y a tu remida por el amor
# te de ella y en la calle
# dale mami que se lleva a pero se suelta
# te va a acarar el cielo
# que esta carrera en la disco y es como el demamio
# si tu quieres perdí con el tiempo
# pero el tiempo a ella no se llama
# la manial esta prenda en mi amor
# los males se ve c
# ----- diversity: 1.0
# ----- Generating with seed: "io...ouh
# dinerolas gataslos party
# plac"
# io...ouh
# dinerolas gataslos party
# placur un hijulle y y bebé
# y dale va a derrar se nos ve saquina
# dentro
# cuanta es bum baila dond yo
# breapeey
# y escapito carao
# tu ama
# y dola cura es una biena
# me cienza deja que se va por harrara vala
# puerta...
# matiche que recorante y los franumiso
# y ella te olvidaría no falla ya tireste el dempeci
# esto es grita se nace
# me lleva en su canita
# me voy aparzo premeas mierpo
# digo
# cégala amor
# ----- diversity: 1.2
# ----- Generating with seed: "io...ouh
# dinerolas gataslos party
# plac"
# io...ouh
# dinerolas gataslos party
# placo se layino explora mio y no no no
# yo te lo beso así no se que no se te voy al ozo
# ardiembra cada
# no recies de una choo el despadripa mbo
# ella tan tu morentale a dateooo puerte reco
#
# quien a mi
# el chomborm que pagandosullarte
# ahora aquistipidad e bailar no ere voluá cuando zagando
# fundia ku yo vay y sece
# que no ves cahoo
# rese ese amormo..zon what rindund
# cámillas bujahinaa
# papi pubet e
# Epoch 10/40
# 999987/999987 [==============================] - 751s 751us/step - loss: 1.4102 - acc: 0.5730
#
# ----- Generating text after Epoch: 9
# ----- diversity: 0.2
# ----- Generating with seed: "um zum ese baile qué rico sabe
# automáti"
# um zum ese baile qué rico sabe
# automático que se lo que te vas
# y hablando el mundo
# esto es que es que esta noche
# que se lo que te ves
# por eso es que se convierte
# si no te vas a mejor se pongan
# y esto es pa que la princilla
# esta noche me llama
# si te ves mas que se que te quiere
# que esto es que es que esta noche
# por eso es que no te vas a estar
# yo te lo dije
# y es que esta noche
# que ahora soy un beso
# y a la piel es el mamo
#
# ----- diversity: 0.5
# ----- Generating with seed: "um zum ese baile qué rico sabe
# automáti"
# um zum ese baile qué rico sabe
# automátido se me viene
# que esta noche baby yo soy el tiempo
# el millo que no importa que te la verá
# para que yo le digo perreando
# te contigo si me prende todo del amor
# oh oh oh oh
# y yo soy lo que puedo estar
# no puedo me dice
# te quedo seguir la pilla suena
# yo te quiero amar
# ven aquí soy el tiempo y yo sabes que no me haces
# de mi vida a mi por eso es la
# dime la calle esta noche
# y con la criminan
# ----- diversity: 1.0
# ----- Generating with seed: "um zum ese baile qué rico sabe
# automáti"
# um zum ese baile qué rico sabe
# automátido corrisita
# es que es cuando se to te la genera
# le llevo que molitas
# y
# que no temperaba con tus alima deja es que su vod
# que eres tu tienen cuerpo
# austa de seguido
# y yo lleto lo mál y homos
# en nunciente tiempo por el peiso te tienen loca dreggater es la foltera
# tiene un cancidienta de mucho sala deady uehh
# leces que pero no vean laita la landha
# traiguro... yeh yeh
# sigonte tu recuerd
# ----- diversity: 1.2
# ----- Generating with seed: "um zum ese baile qué rico sabe
# automáti"
# um zum ese baile qué rico sabe
# automátidelo si tú nlviestá ahí
# y seé pulite
# cabeble a machachy
# el cirobación oro
# who sa mbo gook nifeci gady nem sabe this idrion you cenay estal zapenun je.phe tyco
# lamba oís jame arnada
# dient
# must we ebo
# blaqula rean los anegores jodidos ya la vení
# batado es que me olvides biembo contigo
# séme muevete
# es cael a ti no me aclimenta tú eres
# ópuro quiero arriba.
# hoga jinshos a que prognzo yu
# Epoch 11/40
# 999987/999987 [==============================] - 756s 756us/step - loss: 1.4008 - acc: 0.5758
#
# ----- Generating text after Epoch: 10
# ----- diversity: 0.2
# ----- Generating with seed: "s
# veterano que por nadie se deja vencer"
# s
# veterano que por nadie se deja vencer
# y es que te voy a mener con ella es una
# esta noche no me conoce
# y te conoce en la cama
# te digo la manera
# es que te vas a la manera
# y si no me lleva a darle
# y es que es la mañana
# y yo lo que te va a mi
# y no te veo me encanta
# y no te digas que no te vas
# pero no te veo
# y no me puedo en mi cama
# y tu cara si no te vas a ti
# y si tu no tienes la manera
# y no me llegas la manera
# yo soy la
# ----- diversity: 0.5
# ----- Generating with seed: "s
# veterano que por nadie se deja vencer"
# s
# veterano que por nadie se deja vencer
# y a mi me llama en la disco
# te tiro pa la mañana
# y la nove despariar
# esta noche es la marecha a estar a tus besos
# de tu cuerpo de nosotros
# esta noche yo soy de la mente
# y el loco esta noche no hay los amigos
# y a tantas pa tristir tenerte
# y se cuepro la muerte
# ella me llama el mundo
# me enamora el corazón
# pero con esta libra
# te quiero pa la muerte y no te vas a cambiar
# es que te conve
# ----- diversity: 1.0
# ----- Generating with seed: "s
# veterano que por nadie se deja vencer"
# s
# veterano que por nadie se deja vencer
# el desnidaro pa aprrotar como a pepar
# a feliz
# cómo dime la rebesta
# lo que tye myes
# jefier rico daddy yano
# to soí eso es clique yo me buscan
# no te hablete de peliante
# cosas que decías se que ere del sor
# pa que andabas no son noches a pa tr s...
# por que arribamos lo cuido pesamos qneé tengan yo te quito
# abusa tiro que con enaño tenerla
# la acortuga razalao
# penfyin machead
# buscando la h
# ----- diversity: 1.2
# ----- Generating with seed: "s
# veterano que por nadie se deja vencer"
# s
# veterano que por nadie se deja vencer
# quiero lo priácacio pasa el pa tír la ceraza
# y lo que esta nompora nada a twollubo
# barrio una residero pince
# oyeda la odisia popu derridos
# nadie la laditate chamos pop you estierdo
#
# recongripenira lo totoo  mssicar
# aqui ne cuerdas mosetinos
# patuay younajaje hepresttugosturo
# muchacho con losoqu estin tipiporserupiendo a pasarlo eaheea
# dale el j oh ey
# que los clanditas masilmadad
# poded
# Epoch 12/40
# 999987/999987 [==============================] - 751s 751us/step - loss: 1.3926 - acc: 0.5784
#
# ----- Generating text after Epoch: 11
# ----- diversity: 0.2
# ----- Generating with seed: "asere no me frontee
# dile al pitcher que"
# asere no me frontee
# dile al pitcher que no se pega
# si te vas a entrar
# y estoy contigo
# desde que no se ama
# y esto es que esto es el mundo
# como un party en la calle
# desde esta es la que sea
# si te ves mal de lo que te vas
# y es que estoy en mi manera
# y es que esto es mi corazón
# y se va a entre a mi
# y yo soy la calle en la calle
# y es que te vas a estar
# y el destino y tu me dices
# que te voy a decir que no se va a estar contigo
# ----- diversity: 0.5
# ----- Generating with seed: "asere no me frontee
# dile al pitcher que"
# asere no me frontee
# dile al pitcher que sabe
# mueve suave
# se pone cual es que te vas a estar la calenta
# morena hagamos
# en la estrella
# si tu tienes lo que te metes
# y yo sé que te ves tu hamos rona
# y la sala en la cama
# ella no se va el fuego
# en la cama se por nadie
# dale vivir
# yo me esconda toda la familia
# ella la barre del man
# la luz
# solo maliante
# a mi vero lo que te voy a otratar
# y no lo dajo
# en la vida
# y es que ella
# ----- diversity: 1.0
# ----- Generating with seed: "asere no me frontee
# dile al pitcher que"
# asere no me frontee
# dile al pitcher que mú pidaba ella voy de los alictina
# calenta
# pa enfermar su distinción el puetero
# tengo lo que fuiste que soy estentivo
# y yo soy pero yo
# te montante yo sé que me cuisos
# que me quedas rebala
# voy a rescapar pasegando y las pared
# yo solo quiero hacer el día
# solo volvera en la estrello bebole mi puerto
# y lo hace  abrazo besando
# y deja de ella entodo la portas y me dicen que por que despentir
# ----- diversity: 1.2
# ----- Generating with seed: "asere no me frontee
# dile al pitcher que"
# asere no me frontee
# dile al pitcher que de man op
# hoy yo no no fui tu me racives
# cada vecisa comorotamos y la llora
# no rompertás todo sido para wrcitos
# tengo corazón
# diós lo que
# y yo te amarecio
# un una rapaatecao toda mi a mi
# carta de solo
# pa lo mytina ancegao
# so ya no quiero equisto esa apega
# vichon no se dice soere tanto dándado vuzlan gence al carn
# ozca la sabe ca0
# el cartil ya ella suh aña te bajos peudos
# por sopirun
# Epoch 13/40
# 999987/999987 [==============================] - 734s 734us/step - loss: 1.3856 - acc: 0.5802
#
# ----- Generating text after Epoch: 12
# ----- diversity: 0.2
# ----- Generating with seed: " sin seriedad
# decias que no eras nada s"
#  sin seriedad
# decias que no eras nada sin mi
# hacer el carajo
# esto es algo mas por que te vas a pasar
# que te vas a dar
# que se compré una feliz
# porque estamos en la disco esta esta este esta
# si estas sueño el corazón
# y que estoy con una perderte
# que esta noche esta noche
# si te decirte que esto es pa que estoy me para
# y esta noche esta noche en la cara
# porque esta noche está es la muerte
# que se compario
# si te desperta el cara
# ----- diversity: 0.5
# ----- Generating with seed: " sin seriedad
# decias que no eras nada s"
#  sin seriedad
# decias que no eras nada se lo pare
# te llama de todo lo que tu quieres
# te voy a pasar
# que no estás conmigo
# mi cara se lo envidia me enamora
# si tu no es mi menea tú piensas conmigo
# y a cacar la perderta
# vamos a dar el amor me la baby
# tu sabes que se repres
# pero esta es la disco pa que esta venga
# te siento el care el miedo
# son pa que vamos a dar
# la disco está bajo la subiente
# soy la casa con las ganas me lo real
# ----- diversity: 1.0
# ----- Generating with seed: " sin seriedad
# decias que no eras nada s"
#  sin seriedad
# decias que no eras nada sabe
# mira toda elefo dime de lugar en otra balando
# porque sacistera que vamo poner imposiba
# espera que te puso to por frente contigo
# le enamore que vamo a llorar
# tu sigues baby
# leighe muevete
# roba y dame otro casticlon arriacitos de sandamos
# lengo vivirñale una mástel al zqengo estarica
# me elleta en el dempisimis
# contraba yo
# uaquien te llevo el duro del arigatima
# mami que que yo lloro
# ----- diversity: 1.2
# ----- Generating with seed: " sin seriedad
# decias que no eras nada s"
#  sin seriedad
# decias que no eras nada saber quien es callebla macaalguáp miro y me maisiel pegate retragabar
# y este noche les gatul bienta
# y queda el nuelo otra haga
# ella emplento a cuspartando en llamaron
# quien quiere que vamo hacer la gaina no eso el ayernano
# porque elas ests bebebremos sintidafico forina
# te van a desspritar tanto también
# siempre sondo hola te igu. d
# bibá me aprondamos
# paero aquí sin más que serpanme un hyx
# Epoch 14/40
# 999987/999987 [==============================] - 757s 757us/step - loss: 1.3793 - acc: 0.5822
#
# ----- Generating text after Epoch: 13
# ----- diversity: 0.2
# ----- Generating with seed: "iene
# se pone caliente cuando escucha es"
# iene
# se pone caliente cuando escucha es la calle
# y es que te voy a mener
# y yo sé que te ves para ti
# y si es la muerte y yo
# pero no te vas a toas
# y es que tu cora como si es la muerte
# pero si es mi corazón
# y yo soy el control
# y yo sé que tú eres mía
# tu cuerpo que te quiero
# si tu me tienes como si es la manera
# pero es la calle es tu cuerpo
# y si te acuerdas en la cama
# y si te vas a pegar
# porque estamos la calle
# y es que te
# ----- diversity: 0.5
# ----- Generating with seed: "iene
# se pone caliente cuando escucha es"
# iene
# se pone caliente cuando escucha es el mundo
# la como es un millado
# como tu en la disco es que lo hace
# yo soy la guerre de este los de arriba
# que se hace no quiero
# te diga que me haces tú y yo
# pero hasta el amanecer
# tu fieste y no me vas a ver
# y te conocí en el cuerpo
# y la corazón de pensar
# acércate a mi
# y a mi vida te pone
# mueve el amor y te llevo
# lo mejor que a lo que sienta
# te paso que te hace en mi cuerpo
# por enam
# ----- diversity: 1.0
# ----- Generating with seed: "iene
# se pone caliente cuando escucha es"
# iene
# se pone caliente cuando escucha es
# aquí tus bichitos  de seguro
# y gritar de tros y maren solialo
# el que no me va
# reggaeton dicen que rompo se convierte
# sconsejo y mana tu la tengo que que lo llevo el penso pa poner
# en.o...ew sea aguemoo
# ven
# quémame se jure de ander perreando será la poco
# que yo suve undas son son fillle y llevarte compras algo cabron déjame una de moriro que ya no no no prese
# ti te vuelvo a bar
# augha l
# ----- diversity: 1.2
# ----- Generating with seed: "iene
# se pone caliente cuando escucha es"
# iene
# se pone caliente cuando escucha escapule fummo
# alka mieda
# remojalaribando yensdalez
# y si conmemigendo ese ríchate loca
# me matamos en mindiosmo.
# ya de aguelto
# vuelean cuéndostame
# mundias sensalicendo hapima cuenta pegao besa
# tuyo miro por las baby si congastáslos danarones
# aguabyo a mía....  mager
# maneámitos aguantan con el presundada de lo obiseen
# no vesia pa oevino y regretamos es fuerza
# sube jutános con otrajes rifui
# Epoch 15/40
# 999987/999987 [==============================] - 758s 758us/step - loss: 1.3738 - acc: 0.5836
#
# ----- Generating text after Epoch: 14
# ----- diversity: 0.2
# ----- Generating with seed: "be que yo
# ando siempre con la carterate"
# be que yo
# ando siempre con la carterate
# que el sol en la calle
# y yo soy tu corazón
# y te di contigo
# en tu cara esta noche el amor
# y tu me enamores de tu corazón
# y si no te vas a hacer
# que no se amar
# yo soy dice que tu cuerpo me dicen que te vas
# y no me vas a ver
# y lo que tu quieres te voy a dar
# que no se amar
# que estoy pa la mano a estar contigo
# y yo soy contigo que te vas a todas las noches
# conmigo está propuente
# ella me
# ----- diversity: 0.5
# ----- Generating with seed: "be que yo
# ando siempre con la carterate"
# be que yo
# ando siempre con la carterate
# y nunca va a conterar
# pa la calle como es
# la que me llamas la piel
# de tu cuerpo te very
# pero yo entonces conmigo
# en la disco es de la mañana
# yo te lo dijo nuevo
# se que me pido por destrucir
# pero de ti no ves como me tienes más
# sin mi a mi pasan
# que se acaba el tiempo
# si te trata el sol
# me santa con la prita
# y me digas que se entere
# no te vas a mi lado
# y me encanta y no entre esa m
# ----- diversity: 1.0
# ----- Generating with seed: "be que yo
# ando siempre con la carterate"
# be que yo
# ando siempre con la carterate
# por sin nifutera demostar no existo mami
# no sabe tu gata
# de tu laimetiendo la vuelta frelinteas
# yo te ecceciolo tu vida
# esto yega..oca emriempo
# daleando nonky llata
# solo es batecado
# es que me amo cabra las tarnunciaos
# usted me jivús conmigo
# tranquilo tu sobresas suy polipecio que se me aco te resola
# esta que volvere a un fill
# que mi igo no guarro
# amagnas fuertzas mujer
# que tu me g
# ----- diversity: 1.2
# ----- Generating with seed: "be que yo
# ando siempre con la carterate"
# be que yo
# ando siempre con la carterateritados que nos ella asonos eluin youllllininanteza
# y el que el trmiendo duro
# hoy oobaba sia no tiene algo
# auequefuelosad etéfe haxillanciole siempre con la asancy un probloma
# si no sabe que lucituro
# oh ohohoh honoto ooh ol inshey wionfle withttifid hits ero ghowe
# pow ..hey chacaiting trughters aros fork withll i
# shitter bicching nigh per yo and up you eveevbeci
# di cñandonal calflewent.
# Epoch 16/40
# 999987/999987 [==============================] - 760s 760us/step - loss: 1.3687 - acc: 0.5853
#
# ----- Generating text after Epoch: 15
# ----- diversity: 0.2
# ----- Generating with seed: "terminamos empezaste a salir
# que tu gen"
# terminamos empezaste a salir
# que tu gente es que te voy a decir
# que te lo dijo que te voy a dar
# y me perdone de tu amor
# y te voy a decir que se va a pegar
# y me perdone de la mañana
# y yo soy la cama como se va a llevar
# por eso es que te voy a dar
# y si estás dice que se que me dices que yo
# si no se que te ves
# a la calle es un party
# por eso es que te voy a decir que se dejar
# si es para mí me compro
# y te quiero a mi me pero
# si
# ----- diversity: 0.5
# ----- Generating with seed: "terminamos empezaste a salir
# que tu gen"
# terminamos empezaste a salir
# que tu genes se pone llevar
# no se va a llevar
# pero me pienso en mi cama me lleva
# si no lo creo esta en la calle
# y tu eres tu canción
# y me llamas cuando me mata y te vas a decir que no quiere parar
# quiere que se va a meter
# como la princela y la barra
# la primera se ama mi corazón
# me desesperado con mi como
# yo te voy a recuerdrerse
# si es mi corazón
# es que yo te dio el caraje
# la buena de la para ma
# ----- diversity: 1.0
# ----- Generating with seed: "terminamos empezaste a salir
# que tu gen"
# terminamos empezaste a salir
# que tu gendes dile una vez ustedes de fuego en la lune
# cualdo perreo preonos de decia
# y a moda olvidario todas las mujeres que no puedo y tu
# y mismon el beso ah pa me tra... bien malor
# que ..
# en por chulito fuera mama pose afirctonifle en los pequitalinakes son eefuechas
# el mundo hasta que matamos y trey mono a las jovien es tu piensas
# que llego te lo está no se porque dete blyón
# todo yo te di ya ca
# ----- diversity: 1.2
# ----- Generating with seed: "terminamos empezaste a salir
# que tu gen"
# terminamos empezaste a salir
# que tu gente te deciriz en el caserio quis yo tengo manos grandelas en rosas
# wildia hermami no los pues deunooo pera que no sacías quite quieren mis histtrrikis
# prepajetes pa añosrico y no darees que me a la veó
# el lfice mandita volg
# yep eh eh me acelera escrebubo el rentro
# dugame tengo chivo
# tampocitas de vertacios me lomar que se ama en la piecla
# n el viaje bue pruya booy eeve turicocidad
# ya pa p
# Epoch 17/40
# 999987/999987 [==============================] - 758s 758us/step - loss: 1.3644 - acc: 0.5867
#
# ----- Generating text after Epoch: 16
# ----- diversity: 0.2
# ----- Generating with seed: "es debajo del mantel mujer
# yo voy a ser"
# es debajo del mantel mujer
# yo voy a ser el corazón
# y al mismo que te ves ser el mambo
# y si tu no tienes caliente
# y yo soy tu corazón
# y de mi cara en un barro
# y esto es una moviendo
# si tu no tienes mal
# mi solo tu cuerpo
# y esta noche y te lo voy a dar
# y si tú no tienes miedo
# te digo tu cuerpo
# y si te voy a dar de la mala
# y a ti te voa a pasar
# y no me dejas tu cuerpo
# y me lleva a los pasto
# y que no se la lleva a ti
# y estoy
# ----- diversity: 0.5
# ----- Generating with seed: "es debajo del mantel mujer
# yo voy a ser"
# es debajo del mantel mujer
# yo voy a ser al corazón
# y el fin de recordar el tiempo
# y ahora te desesperaba no es tuyo
# y aquí no hay nada no se me atrevo
# de tu cara esta noche con los que me llegan esta
# con el piso a la cabeza
# a ti te vas a mi
# y me activo se que me gusta
# lo que tú me pide en mi manera
# cuando estoy pendiente y estoy en mi vida te voa
# ella la noche es bien
# que tú por eso no te miras
# por ti no no no no no no no n
# ----- diversity: 1.0
# ----- Generating with seed: "es debajo del mantel mujer
# yo voy a ser"
# es debajo del mantel mujer
# yo voy a sermercesa
# no te pasó y en tu cuerde cuando lo que tu
# tus males que yo te dije que me conierjo
# y hasta el amar con fuera amigos
# que olvides acabao
# baby die tu fatina como joseoy después doy
# todos pana corre
# demilisticandime del cehetro de coramos al amor
# como la nami cuando ella no creen la llgen los amigos
# por si no me sabes y por mi
# quiero vivir condinos
# cuando tu quieres como un flow
# m
# ----- diversity: 1.2
# ----- Generating with seed: "es debajo del mantel mujer
# yo voy a ser"
# es debajo del mantel mujer
# yo voy a ser
# mejor de activa se
# puede subir
# un solo raito
# ala viviada una abesa solo cuenta shorty
# como la gente mas por.ar de enrar
# al deoba flikellone bien bestyoro algo
# tu nena miccame ya quién to el alveria
# y soy lopo con brins amoro ore haliendo
# me quitas eleciste rutichrumble
# osóuído si sin dónyes aveie wheadow bien deleateron salir
# in noche el corazko deddy
#
# corre imaginar
# wow yo go que ba
# Epoch 18/40
# 999987/999987 [==============================] - 753s 753us/step - loss: 1.3603 - acc: 0.5879
#
# ----- Generating text after Epoch: 17
# ----- diversity: 0.2
# ----- Generating with seed: "s amigo y lo hacemo escondido
# y yo solo"
# s amigo y lo hacemo escondido
# y yo solo quiero
# como yo soy tu cuerpo
# y es que te desespera
# y si te vas que no se acabe
# si te vas a mi corazón
# y te quiero te vas
# y que no me llamas
# que estoy mal amor
# y si te desperta
# y tu cuerpo me llamas
# y si te quieres que estoy despecto
# y si estas como un party
# si tu me estas con el carte
# si te vas a mi cara
# tu cuerpo es que te desespereso
# y si no te vas a toa
# y a tu corazón
# es que t
# ----- diversity: 0.5
# ----- Generating with seed: "s amigo y lo hacemo escondido
# y yo solo"
# s amigo y lo hacemo escondido
# y yo solo te vea tamos
# y es que estoy en tus labios
# esta noche es que tú te me llamas
# te me la vera con cualquier arreaciones de sexo
# si te hace sin amigo
# me des yo sé que te vas
# cuando me presenta
# te veas llamada
# que esto es tu noche es mi cangulo
# tu cuerpo como el party el party pa que salga de los hombre
# por el corazón
# el corazón yo se que te enamores
# si estas lo que te pongas
# y me conocist
# ----- diversity: 1.0
# ----- Generating with seed: "s amigo y lo hacemo escondido
# y yo solo"
# s amigo y lo hacemo escondido
# y yo solo tengo monoo
# tu se sientes si te vagas de preten
# lo este leciono
# como decías de mi otra para dime
# y me quieres que le vas vaida
# sólo tu me sacas
# quiere parar muchas facillbas millonas
# y me aciente...
# que esa es pa vente también
# tragana ieye me guaya si el que te día tu vivo
# esto es amorme donde estó huelo
# y delarte prenda el verdion de resustad
# nos perdís...
# quillarte yo tu te ves bie
# ----- diversity: 1.2
# ----- Generating with seed: "s amigo y lo hacemo escondido
# y yo solo"
# s amigo y lo hacemo escondido
# y yo solo tu yalía forta también
# yo soy tuyo w a que grerra
# ir bot this the rescandoel era frea
# daddy yankees miles te vez solo yaba
# dáblo que a él tu eres spendillé
# hemixa si me renfanta
# he dile que si
# se como quodas los que tu amor eras todos cabrones
# en olompoto yo voy a mí mete él
# no sábe la boriane tengo bailletos los cuno el diamio
# aqui no temeusita y yo
# haciento abazado cambro styroknnú
# Epoch 19/40
# 999987/999987 [==============================] - 753s 753us/step - loss: 1.3565 - acc: 0.5892
#
# ----- Generating text after Epoch: 18
# ----- diversity: 0.2
# ----- Generating with seed: "d no vende ni en ebay
# no das pa na
# con"
# d no vende ni en ebay
# no das pa na
# con el carro
# no es que me dejas yo
# si tu no estas
# que te pongo a mi
# y es que te doy lo que te hace
# a mi me hace cara
# y esta noche es que te doy
# y te estoy contra el caro
# y de la calle es la noche estás
# y si el que te vas a decir que se va
# que estas sentimiento
# y de mi corazón
# que se va a lo que tu quieres
# y a ti te voy a dar
# y de mi corazón
# y si no te desesperto
# no me dejo esta noche
# ----- diversity: 0.5
# ----- Generating with seed: "d no vende ni en ebay
# no das pa na
# con"
# d no vende ni en ebay
# no das pa na
# contra la calle
# y yo no se voy a dar la dolas
# solo de dios pa que esta noche
# que estás en el amor
# sin ti no te prepasas ti
# y yo te voy a decir qué
# son las cosas conmigo
# que se como ella es mi estarte
# la noche a tu cara esta perdí
# con la boca me he palabro
# que estoy pendiente a tu mariando
# te voy a cabrar lo mio
# si fue adiesto a ti
# y que estás aquí
# todos los piel nada
# yo soy maluma
# y l
# ----- diversity: 1.0
# ----- Generating with seed: "d no vende ni en ebay
# no das pa na
# con"
# d no vende ni en ebay
# no das pa na
# conviendo malo que un hombre y bebe
# q las vaces sonos te fuiste cuando estoy
# cuando romos ya con el dolor
# no porque lo cuideces de revolvertarnas de uso
# flomos de la millaoa era mondo pilos
# hoy que si hipomos y crepenfinalientos sbienen un belleco
# sabes huele a casa calenta todos las ganas
# con amor sin otra visiade esn que vaysome solo en mi discoteca
# vergall que te toquen un gustón
# calor te
# ----- diversity: 1.2
# ----- Generating with seed: "d no vende ni en ebay
# no das pa na
# con"
# d no vende ni en ebay
# no das pa na
# conmigo dondo flovere
# yeah i naca
# de movelaristal pa azotao amor bebé florta famtiilo
# liento dontellos nos jubvertesas ir baby
# los polmigos una renga booh sandan yo tengo y no busuro
# de villaces el dío chi
# para unbiarlo todo lo hisio
# que secreto ahí baby yo siempre una un solos
# un sinterio de esperadorea
# peentete estamo sharuran eacencidad
# comeles siempre que siento y hasta un escabro ni
# Epoch 20/40
# 999987/999987 [==============================] - 761s 761us/step - loss: 1.3532 - acc: 0.5893
#
# ----- Generating text after Epoch: 19
# ----- diversity: 0.2
# ----- Generating with seed: "lora aprende
# y tú ya sabes bastante
# co"
# lora aprende
# y tú ya sabes bastante
# como la mano a la cara
# y a tu corazón
# me encanta la calle
# y yo soy el que te haga a mi maridad
# por eso es que te vas a toa
# y es que te va a pasar
# si tu no tienes mano de la calle
# y es que te va a parar
# esta noche es mi cama
# y a ti te va a pasar
# y es que te haga tan por descontrola
# y es que te enamoras
# y tu para mas que te vas a enamorar
# y te vas a parar
# si te pongas con el cara
# es que
# ----- diversity: 0.5
# ----- Generating with seed: "lora aprende
# y tú ya sabes bastante
# co"
# lora aprende
# y tú ya sabes bastante
# con la mano y te amor
# y te lo haga nada mas que hacero para encontrar
# es la comba bien lo que te va a ser la vida
# es que amambiciado mas de lejos
# y se nos vamos pa la calle es el mundo
# tú eres mi corazón
# y no te trata me encanta
# ...
# y es que me dejes que te dejas
# ----- diversity: 0.5
# ----- Generating with seed: "de razones que no esperan nada
# ya puedo"
# de razones que no esperan nada
# ya puedo estarte todo lo que sientes que será
# por ti tú me tienes más
# sigue es tu mejor
# y estás con una corazón
# me enamoras de algo
# el rescale
# si no se la lleva
# sabes que tu no sabes que se envidia
# de que en el corazón
# y con el corazón tu eres mía
# como un reggaetón
# se lo que te va a ser lo que yo llama
# la noche si te vas a estar mami
# te digo que el calor y yo soy el recuerdo
# como te voy a da
# ----- diversity: 1.0
# ----- Generating with seed: "de razones que no esperan nada
# ya puedo"
# de razones que no esperan nada
# ya puedo eúna pa moría lo que rico
# fuerzato
# siga abraza me recue delenecela
# si tu mai terreme llevo me diga al calor
# porque pues me hacemos tu amene de noche
# un lugar el arro
# sigue hoys foco la brisa
# quiero noche que me gusta la cantar
# si tu eramos de la nova
# dale y fracaso
# no me rentes te alegas
# de noche
# que yo me quitan pa ver mentiriara
# como lo que está amor para contemiguera
# con mayor mu
# ----- diversity: 1.2
# ----- Generating with seed: "de razones que no esperan nada
# ya puedo"
# de razones que no esperan nada
# ya puedo negrar chica hielo ala guerre que aprensa ah
# heeh
# masind cauter
# colke in tehoo terena mi
# que dar
# vamoso intengo dios
# en failed ajan va y no llamarte y no sea pulsable con las lo que te llega
# yo
# granda como te hace
# que un alagnauablesio hasta que paso con el recomba
# que botella risco logre
# supe años besos día porque
# color como chamalo leta
# coy cabiza
# chelle ser mode jugaaas r.pribe e
# Epoch 35/40
# 999987/999987 [==============================] - 742s 742us/step - loss: 1.3245 - acc: 0.5983
#
# ----- Generating text after Epoch: 34
# ----- diversity: 0.2
# ----- Generating with seed: "que soy celoso
# venga a las manos del fa"
# que soy celoso
# venga a las manos del fantasia
# y que no te dejas la mano
# que te lo da la noche
# por eso estoy pa que se lo quiero
# no te puedo a ti
# esto es mi mujer
# que esta noche
# por eso no te dio lo que tú quieras
# que te amas de mi corazón
# y a tu corazón de mi corazón
# que no se acaba la vida
# se siente saber
# me dice que no te dejas más
# y te dejas mi
# no sé que te deja el cuerpo
# y no te vas a decir
# que esto es mi cara
# esta
# ----- diversity: 0.5
# ----- Generating with seed: "que soy celoso
# venga a las manos del fa"
# que soy celoso
# venga a las manos del farruo
# y que se lo que te haces alguien
# no te enamoras como yo
# y la matinito
# con el cartel del cambio el tiempo
# y quiero que a ti te vas a llevar
# no te conoce en una razón
# y a ti te quiero tengo para otro que ella
# de amor que me enamoraría
# te lo quiero comer
# yo no sé por qué tú me gusta
# bailando pa que te acuerdas
# se fuera un momento se acaba
# si no estás en la calle a mi me di
# por más
# ----- diversity: 1.0
# ----- Generating with seed: "que soy celoso
# venga a las manos del fa"
# que soy celoso
# venga a las manos del fachubla
# liter que tienen parte rappp
# si tal pasate la palaba gente
# en que quiero a belar
# que no te mismentes diferente ay o
# esto... baba una recorque el nockítolo el put turo
# yo aunque te me quedas
# es una garióa detenerna donde asuete pa alganeia
# pero estamos socio
# aquí no queremimar
# la pirta que la nena sola tú la me hu a
# di pa que el caló
# yo usted
# y yo amor aima en el moneo
# ella olv
# ----- diversity: 1.2
# ----- Generating with seed: "que soy celoso
# venga a las manos del fa"
# que soy celoso
# venga a las manos del fanilia
# en cogaro
# soy un par
# tu no tiene asi la prendes
# uu zisba el montonos
# bellabando el día fuero baca
# tiene dice plejaron más
# contentarte que yo lo hay algo que auntante
# me llamen hechacerakatdal van
# a que lo voa si quiere que la cortenta tenintete no el roba
# y yo sigo pero se árlartelo
# hacierda hores mordiposio
# endoncho holouhhhhhh
# ni al sskw
# único gestinto lo sabes peleo al esper
# Epoch 36/40
# 999987/999987 [==============================] - 735s 735us/step - loss: 1.3230 - acc: 0.5984
#
# ----- Generating text after Epoch: 35
# ----- diversity: 0.2
# ----- Generating with seed: "a duro buscate un buen seguro dale mas m"
# a duro buscate un buen seguro dale mas mami
# que esta noche yo te voy a dar
# y si tú me pones de lo que sientes que no es pa mi
# de la cama me dice que no es un poco
# y es que tu eres mi vida
# por qué te voy a montar
# si tu quieres mami que la verdad
# yo te lo da mucha control
# es que tu me estás con la pista
# y el corazón mi corazón
# y si te vas a estar con ella
# que se me volve en mi corazón
# y es que me dejas tu cara
# yo soy tu cuerp
# ----- diversity: 0.5
# ----- Generating with seed: "a duro buscate un buen seguro dale mas m"
# a duro buscate un buen seguro dale mas manda
# yo soy un aire y esto es que me lleva
# de la mañana de eso
# y la vida se te haga un pistor
# cabrón de amor
# pero tu quieres mami tu cuerpo esto es
# y tu me encanta con romo
# yo soy un poco nadie conocerte
# que así
# esta noche pa que la pone de mi a la misma
# y la voz
# deja es que la monto
# que tu corazan
# solo si estamos ando con el corazón
# si te voa las cosas pa que tu me probosan
# y a mi
# ----- diversity: 1.0
# ----- Generating with seed: "a duro buscate un buen seguro dale mas m"
# a duro buscate un buen seguro dale mas mante mueverio
# joden
# arring ning my neim the woald
# im on ygur ebes pund my oye
# when is shotster sight
# dont everling shatrour  eió juna stoplad
# im giro cang na ses
# bay que la boma
# del bando
# mía un jodizo ya no puedes que te reocos
# que llegan tantos el corazón la vida
# quiero que tu vensscenna y lentamente y aguantero pero no vienes ddddyyyya
# sin mi la calle
# arremojo es pa bay
# tengo tod
# ----- diversity: 1.2
# ----- Generating with seed: "a duro buscate un buen seguro dale mas m"
# a duro buscate un buen seguro dale mas malo
# como un fruto en tu forras lo que tengo una tellgao
# maliesda yo raso dinerte
# ella noy tran brija a su reames mata enpaña
# quier llamarme tu ven
# bien que nunca creas irmeies. dale un punto
# tus amigqúsico
# bolando concriando to
# que bien volvimiento
# es y morido... tenemos alra un vidado más
# si él los mundo y tratiiotarala otra vez
# no sé em visío así rásd llanturo
# me enanda lo hlamo olo
# Epoch 37/40
# 999987/999987 [==============================] - 757s 757us/step - loss: 1.3221 - acc: 0.5989
#
# ----- Generating text after Epoch: 36
# ----- diversity: 0.2
# ----- Generating with seed: " hiciste
# la vida te esta cobrando
# y ah"
#  hiciste
# la vida te esta cobrando
# y ahora que se le va a poner
# y tu cuerpo es una casa
# esta canción por el mambo
# mami que la verdad
# si te vas a todas las mujeres
# y si te digas que no te dejas
# y te lo daré
# te quiero a ti
# y que no te preguntas
# que no te dejas mi
# y si te dije que te dije que esto es una maridad
# si estas contigos
# que se prende el tiempo
# si te quiere que te desespera
# y yo soy tu cuerpo
# esto se pone de mi car
# ----- diversity: 0.5
# ----- Generating with seed: " hiciste
# la vida te esta cobrando
# y ah"
#  hiciste
# la vida te esta cobrando
# y ahora sientes que sienten que las caminos
# soy el que le jura pa que la cangri a respartela
# se ve la calle me encanta
# te digo que me dije hace lo que te vas
# te digo que no hay nada
# no te mata la mueve
# que esta noche nos fuma el mundo entero
# verdadón
# pa que no se lo viene
# ella no hay nada bendes
# y si esta noche nos vamos a ser la pared
# si me prestanta contigo
# tu eres bien
# el corazón de bo
# ----- diversity: 1.0
# ----- Generating with seed: " hiciste
# la vida te esta cobrando
# y ah"
#  hiciste
# la vida te esta cobrando
# y ahh a
# pal que los meoblas confinos
# soy yo para ti me fuiste que te acérsa botandame
# pero sin nadie sofresita
# salcha todas nada chinga
# yo soy para las acerque es de mi
# buscara no olvidar
# malaminita le dije yo siente muncila y en intel
# no siene poké como te lleve
# nuevon a dalt fantito
# si tu no la vas a me wiste de la bala
# es palamos
# después conocolar más
# qué pasa digo como un ista dijo la
# ----- diversity: 1.2
# ----- Generating with seed: " hiciste
# la vida te esta cobrando
# y ah"
#  hiciste
# la vida te esta cobrando
# y ahí dime cáha que ella dide la lucha cada rapapia y yo
# contigo porque hija cope sky que bien los guerro
# valiantes
# donqfece firñy
# we keeve good blastllim
# hot
# more
#
# ty .rb welry girl ..didatdari down breete idnet sde ibricky ge zighta
# he digapros mallata
# este agva felicipita syes know
# tú lo que me decian esvemos expuestas quién arrito pevitaino te quiero ver
# y conmigo piendo caro na cuanta
# Epoch 38/40
# 999987/999987 [==============================] - 757s 757us/step - loss: 1.3216 - acc: 0.5988
#
# ----- Generating text after Epoch: 37
# ----- diversity: 0.2
# ----- Generating with seed: "ntra la pared
# se produce el impacto bab"
# ntra la pared
# se produce el impacto baby
# y no te vas a pegar
# y yo soy tu cuerpo es que te digo que estoy contigo
# y yo soy tu cuerpo te voy a dar
# y esta noche es que te voy a dar
# y a la cama y la mano a la corazón
# en la calle es la compañe la mano
# y es que te voy a dar
# y esta noche está en la cama
# y a to los distantes en la cama y la compase
# y a tu cuerpo es la cama
# si tu me muero
# y a ti tu eres mía
# y tu me tienes de mi man
# ----- diversity: 0.5
# ----- Generating with seed: "ntra la pared
# se produce el impacto bab"
# ntra la pared
# se produce el impacto baby
# la que le enseñas la ladita
# en la cama y se pase a la cabeza
# porque tengo lo que te hablen de mí
# yo se que te acuerdo
# por que yo te confuesta tengo que amar
# yo te quiero a lo que se va a ver
# y si me diste duro con el amor
# por que no sientes que no te dijo la real
# si se hace la que quiera ver
# todo lo que sientes tengo
# que yo quiero siento que te vayas a la media y cuando tu mira
# la ca
# ----- diversity: 1.0
# ----- Generating with seed: "ntra la pared
# se produce el impacto bab"
# ntra la pared
# se produce el impacto baby romper sin oca
# si el bllinio era dance pa moripulad brillar
# después de tu recuerdo amor cuando problemas
# cuánto le ver al arriezar sus etres
# yo aguanto de a la guerretie maquing a quieren biene en el astuelo
# esas mujer que sabas un resido
# mami como pillacios o
# cuento sexy yo si está déjame tu me pongo son
# yo comvorta respate enlencantos mal del gatátito
# torías lo que haces tanto
# no qu
# ----- diversity: 1.2
# ----- Generating with seed: "ntra la pared
# se produce el impacto bab"
# ntra la pared
# se produce el impacto baby pa
# dy farra  perriones
# no te llamo vina tiempo que yo pelearon uso g tp sticre
# sobra litea
# marvent pitos...
# tú quieres despugo en ti no é lasis miraciones
# hotalir
# sin ti pide diqueste rebola
# y juntos los regsé lo maley
# chlochon
# llego po te aguanta el moy
# pensar i turrilliciones  el tiempo
# y antes pierdo antes que por una gono me va a bebiare vieno
# papi que reggaeeron
# no improdib
# Epoch 39/40
# 999987/999987 [==============================] - 754s 754us/step - loss: 1.3205 - acc: 0.5997
#
# ----- Generating text after Epoch: 38
# ----- diversity: 0.2
# ----- Generating with seed: "as
# modelando en su motocicleta
# por ahi"
# as
# modelando en su motocicleta
# por ahi quiero que te voy a decirte
# que estas contigo
# yo soy maluma
# y ahora me hace para mi
# esta noche no puede estar contigo
# y yo soy tu corazón
# y si tú me dices que te voy a rendencar
# y yo soy maluma
# pero no pueda el amor
# y es que te voy a dar
# y esta ready y esta noche esta calle
# pa que te lleva a calle
# y esta noche está a amarte
# y me dejas tu cama
# y a ti te voy a rendencar
# pa que te voy
# ----- diversity: 0.5
# ----- Generating with seed: "as
# modelando en su motocicleta
# por ahi"
# as
# modelando en su motocicleta
# por ahi hasto mi corazón
# el mundo están las puestos amor
# estas mirada
# yo se que te hago me queda tu corazon
# tranquilo
# yo te lo di calor
# de carro que te di como pa ti
# y que la pone de la calle
# y a la disco ya esta algo
# pasa la puita como un borty
# si estas tuyando tenerte donde están las
# pa los de dias que esta noche en ti
# solo tu piel como yo
# por eso nos como yo no puedo negar
# y yo soy malum
# ----- diversity: 1.0
# ----- Generating with seed: "as
# modelando en su motocicleta
# por ahi"
# as
# modelando en su motocicleta
# por ahi eh ke quedate áalugú
# las cima hacemos por ti
# entre las ganas dile que té llente todo cuno y yo
# yo no llego en la mila
# no te sabeso contigo ni zabito
# esos corazón de acarisión
# olvidapa
# vamos a ganarmel te sacen de cosas qgamas
# mami la chané es tus buegos
# pidiendo en tiempos conquinas
# entonces el de los mejores
# desgués damos todo el trese
# bien somos más que banco en dormir
# pa avano mag
# ----- diversity: 1.2
# ----- Generating with seed: "as
# modelando en su motocicleta
# por ahi"
# as
# modelando en su motocicleta
# por ahi pospepa roba una gentea robe en ónentragándos
# los cantros suovpue
# ma se candll dume dale me que tú pasas
# dice lo reakoitoz
# caminan
# el que te excame calidutas yankeo
# anda frvornemo... sujave del nadia merticiones mai carse estamos son repetivo
# wich
# mía noche cagandeme de aquí
# exaven mua las ho
# tada la huma rolld quinás cumblan
# aprecia...
# con otro pensar despues osiga ideanadando mujere
# Epoch 40/40
# 999987/999987 [==============================] - 750s 750us/step - loss: 1.3196 - acc: 0.5995
#
# ----- Generating text after Epoch: 39
# ----- diversity: 0.2
# ----- Generating with seed: "rir de amor a que el amor me falte
# en c"
# rir de amor a que el amor me falte
# en calenaza
# y se que te vas a decir
# que esta noche me enamora
# que no puedes contro esto es pa que la calle
# y si te metes como si es pa que te paso
# si se prende el corazón
# el calor me dejo el paso
# con esta pena de la calle
# y si esta caliente
# esta noche me pone mal
# si te pone me prendes que te voy a dar
# pero te voy a amar
# que si te quiero te vas
# si te vas a descontrolar
# y te voy a dar
# y s
# ----- diversity: 0.5
# ----- Generating with seed: "rir de amor a que el amor me falte
# en c"
# rir de amor a que el amor me falte
# en callejeta
# te pega ahora sabe que se lo hago ma
# te llame a amarte
# como los paso que no hay nadie
# que no pare nada a ti
# y me dice por la cama
# si el tiempo que te veo al cantar
# que no sabes que así no eras
# de ver amor
# y tu y yo
# una casa con tu mirada
# si te voy a dar de lo que hay
# que yo no dejes de algarete
# y tu y yo soy carros
# tu no paras ser dale
# a ti te encanta
# si tu quieres con lo
# ----- diversity: 1.0
# ----- Generating with seed: "rir de amor a que el amor me falte
# en c"
# rir de amor a que el amor me falte
# en caminarte el faítela de recorrer
# abrena me pasar pa mi tu i te voy a tus palidos
# quiero defellar se rinta
# aquí lo percer le pego al ella tu pierda a quere lo que pide mi penter
# si no aprendes nada
# me siento te meto y traquel siempre se olvida provocante y tu queen dice palanon
# se le gusta ala niña su pareda
# sé que te poo derendele por lo comportas con hoy
# tralgando
# y a mí te la paso
# pa q
# ----- diversity: 1.2
# ----- Generating with seed: "rir de amor a que el amor me falte
# en c"
# rir de amor a que el amor me falte
# en cuidarte el tragle
# en disco tu tu baby casfridada holas me escapillema
# lajo tabilan pa me toja
# stara interier ard buenos hooehh withos
# cuando nosoé nace rica en el ellao
# y apunto y eres ma malo lejarte
# daje dijo me como conozco
# q eviliando tus genes terminamos real
# es proque deniciriden
# no siento lo que la fallaza
# la majiao con el cansello
# ek sho upring thats like you can sde
# froarboto
#
# Saved model to disk as model.h5
#
#
# ========== Model summary ==========
#
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 128)               89088
# _________________________________________________________________
# dense_1 (Dense)              (None, 45)                5805
# =================================================================
# Total params: 94,893
# Trainable params: 94,893
# Non-trainable params: 0
# _________________________________________________________________
# None
